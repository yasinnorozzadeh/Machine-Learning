# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
balloon_width=np.random.normal(8,50)
balloon_length=np.random.normal(6,10, 50)
balloon_weight=np.random.normal(0.002,0.001,50)
                                
melon_width=np.random.normal(15,5, 50)
melon_length=np.random.normal(20,5,50)
melon_weight=np.random.normal(6,5,50)

# %%
fig=plt.figure()
b_m = plt.axes(projection='3d')
b_m.scatter(data[0:50,0],data[0:50,1],data[0:50,2],c='c')
b_m.scatter(data[50:,0],data[50:,1],data[50:,2],c='m')

b_m.set_xlabel('Width')
b_m.set_ylabel('Height')
b_m.set_zlabel('Weight')
# Out:
# Text(0.5, 0, 'Weight')
